# %%
df = (spark.read
        .option("header",True)
        .csv('/Volumes/world_cup_2026/bronze/raw_files/fifa_world_cup_enhanced_1974_2022.csv'))

display(df)

# %%
# %sql
SELECT * FROM world_cup_2026.gold.team_historical_performance
